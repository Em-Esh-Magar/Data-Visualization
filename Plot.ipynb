# %% [markdown]
# <a href="https://colab.research.google.com/github/Em-Esh-Magar/Data-Visualization/blob/main/Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Plot
import matplotlib.pyplot as plt
import numpy as np

x = np.array([3,8])
y = np.array([5,20])

plt.plot(x,y,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5,6,7])
y = np.array([9,4,6,3,11,7,10])

plt.plot(x,y,"o")
plt.show()
